# %%
# import random
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline

def varyValue(rate, avg):
    if rate == 0 or avg==0:
        rate = 1.01
    return

def share_add(total_v, biWeek, weight, ):
#Total spend on a bi-weekly rate for a given share given a % of the total 36k per year
#rounded to the 4th digit for upper/down values
    total_v = round(biWeek * (.01 * weight), 4)

#find how many shares that buys
    share_start += round((total_v / 300), 4)
#2.9 shares for the first iteration @ 300 usd
#make dynamic


    
def eoy(biWeek, v):
    total_voo, total_vym = 0,0
    voo_share, vym_share = 26, 53
    voo_div, vym_div = 1.178, .5544
    total = 0
    i = 0
    v = v * 26
    for i in range(0, v):
        if i % 13 == 0:
            total_voo = round((biWeek *(.01* voo)), 4)
            voo_share += round((total_voo / 250) + (voo_share*voo_div)/300, 4)
            total_vym = round((biWeek *(.01*vym)), 4)
            vym_share += round((total_vym / 70) + (vym_share*vym_div)/90, 4)
            total += 1.10*(total_voo + total_vym) + (voo_share * voo_div) + (vym_share * vym_div) 
        elif i % 6 == 0:
            total_voo = round((biWeek *(.01* voo)), 4)
            voo_share += round((total_voo / 250) + (voo_share*voo_div)/300, 4)
            total_vym = round((biWeek *(.01*vym)), 4)
            vym_share += round((total_vym / 70) + (vym_share*vym_div)/90, 4)
            total += total_voo + total_vym + (voo_share * voo_div) + (vym_share * vym_div) 
        else:
            total_voo = round(biWeek *(.01* voo), 4)
            voo_share += round(total_voo / 250, 4)
            total_vym = round(biWeek *(.01*vym), 4)
            vym_share += round(total_vym / 70, 4)
            total += total_voo + total_vym
            i+= 1
            print(str(i),
    #             '\t\t' + str(round(total_vym, 2)) + 
                '\t\t' + str(round(vym_share, 2)) +
                '\t\t' + str(round(voo_share, 2)) +
                '\t\t' + str(round(vym_share * vym_div, 2)) + 
                '\t\t' + str(round(voo_share * voo_div, 2)) + 
                '\t\t' + str(round(total, 2)))
        total_val = total_voo + total_vym
#     print(str(total_val) + '\t' + str(voo_share) + '\t' + str(total_voo))


yearly = 36000.00
voo = 62.9
vym = 37.1
biWeekly, weekly, monthly, quarterly = round(yearly/26,2),round(yearly/52,2),round(yearly/12,2),round(yearly/4,2)

# %%
eoy(biWeekly, 5)

## current target for quartlery div 30.63

# '{:.4f}'.format(yearly)
# Out:
# 2 		77.79		37.71		43.13		44.43		4920.08
# 3 		90.02		43.52		49.91		51.27		7227.77
# 4 		102.25		49.33		56.69		58.11		9535.46
# 5 		114.48		55.13		63.47		64.95		11843.15
# 6 		126.71		60.94		70.25		71.79		14150.84
# 8 		151.95		72.79		84.24		85.75		18922.59
# 9 		164.18		78.6		91.02		92.59		21230.28
# 10 		176.41		84.4		97.8		99.43		23537.97
# 11 		188.65		90.21		104.59		106.27		25845.66
# 12 		200.88		96.01		111.37		113.11		28153.35
# 15 		240.13		114.21		133.13		134.54		35800.46
# 16 		252.36		120.02		139.91		141.38		38108.15
# 17 		264.59		125.82		146.69		148.22		40415.84
# 18 		276.82		131.63		153.47		155.06		42723.53
# 20 		302.99		143.76		167.98		169.35		47662.61
# 21 		315.22		149.56		174.76		176.19		49970.3
# 22 		327.45		155.37		181.54		183.03		52277.99
# 23 		339.68		161.18		188.32		189.87		54585.68
# 24 		351.91		166.98		195.1		196.71		56893.37
# 26 		378.54		179.25		209.86		211.16		61916.15
# 28 		405.33		191.57		224.72		225.67		67199.06
# ...

# %%
t_val = 322940.79
total_val = 321325.41
total_val * 5
nval = total_val * .6
nval * 5
# Out:
# 963976.23
